# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
z = pd.read_csv("C:/Users/DELLPC/Desktop/machine learning/read.csv")
z
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5     11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6     11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7     11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8     11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9    11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
# 10   11/11/2007  Canberra      9.1     25.2       0.0          4.2      11.9
# ...

# %%
plt.plot(df["MinTemp"],df["MaxTemp"],c="brown")

# %%
plt.scatter(df["MinTemp"],df["MaxTemp"],c="black")

# %%
sns.distplot(df["MinTemp"],kde=False)
# Out:
# C:\Users\DELLPC\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df["MinTemp"])
# Out:
# C:\Users\DELLPC\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df["MinTemp"],kde=True,color="c")
# Out:
# C:\Users\DELLPC\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.kdeplot(df["MinTemp"],shade=True)

# %%
sns.distplot(df["MinTemp"],kde=True,hist=False,rug=True,color="orange")

# %%
sns.jointplot(df["MinTemp"],df["MaxTemp"],data=df)
# Out:
# C:\Users\DELLPC\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\DELLPC\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(df["MinTemp"],df["MaxTemp"], kind="hex", color="r")
# Out:
# C:\Users\DELLPC\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\DELLPC\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.kdeplot(df["MinTemp"],df["MaxTemp"])

# %%
sns.jointplot(df["MinTemp"],df["MaxTemp"],data=df,kind="kde")

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(tips)

# %%
sns.stripplot(df["MinTemp"],df["MaxTemp"],data=df)

# %%
sns.swarmplot(df["MinTemp"],df["MaxTemp"],data=df)

# %%
sns.boxplot(df["MinTemp"],df["MaxTemp"], hue="Location",data=df)

# %%
df["rain"] = df["RainTomorrow"].isin(["NO","YES"])
sns.boxplot(df["MinTemp"],df["MaxTemp"], hue="rain", data=df, dodge=False)

# %%
sns.barplot(df["MinTemp"],df["MaxTemp"],hue="Location",data=df)

# %%
sns.countplot(df["MinTemp"],data=df,palette="Reds_d")

# %%
corr = df.corr()
sns.heatmap(corr)

# %%
t1 = np.arange(0.0,5.0,0.1)
t2 = np.arange(0.0,5.0,0.02)

plt.figure(1)
plt.subplot(121)
plt.plot(t1,t1,'bo',label="t1")
plt.plot(t2,t2,'g',label="t2")
plt.title('subplots')

plt.subplot(122)
plt.plot(t2,np.cos(2*np.pi*t2),'r--')
plt.grid(True)
plt.text(2.18,0.8,r'cos func')
plt.show()

# %%
sns.lmplot(x="Evaporation",y="MaxTemp", data=df, hue="Evaporation")
